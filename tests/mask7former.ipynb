# %%
from transformers import (
    Mask2FormerConfig,
    Mask2FormerForUniversalSegmentation,
    SwinConfig,
)


mask7former_config = Mask2FormerConfig(
    backbone_config=SwinConfig(image_size=128, patch_size=4, num_channels=7),
)
mask7former = Mask2FormerForUniversalSegmentation(config=mask7former_config)
